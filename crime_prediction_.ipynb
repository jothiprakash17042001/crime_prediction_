# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
df = pd.read_csv("/content/crime-data-1000.csv", encoding='latin-1', engine='python', on_bad_lines='skip')

# %% [markdown]
# **Display the first five row dataset**

# %%
df.head()
# Out:
#          ID Case Number                    Date                   Block  IUCR  \
# 0  10278872    HY467389  10/18/2015 11:50:00 PM      060XX S VERNON AVE  0560
# 1  10278895    HY467411  10/18/2015 11:50:00 PM         011XX E 82ND ST  0486
# 2  10278866    HY467390  10/18/2015 11:50:00 PM         026XX E 83RD ST  1811
# 3  10279273    HY467434  10/18/2015 11:40:00 PM         035XX E 97TH ST  041A
# 4  10278909    HY467416  10/18/2015 11:36:00 PM  078XX S SOUTH SHORE DR  4388
#
#     Primary Type                   Description     Location Description  \
# 0        ASSAULT                        SIMPLE  RESIDENCE PORCH/HALLWAY
# 1        BATTERY       DOMESTIC BATTERY SIMPLE                APARTMENT
# 2      NARCOTICS  POSS: CANNABIS 30GMS OR LESS   DRIVEWAY - RESIDENTIAL
# 3        BATTERY           AGGRAVATED: HANDGUN                 SIDEWALK
# 4  OTHER OFFENSE   VIO BAIL BOND: DOM VIOLENCE                APARTMENT
#
# ...

# %% [markdown]
# **Display the bottom five row dataset**

# %%
df.tail()
# Out:
#            ID Case Number                    Date                 Block  IUCR  \
# 994  10277794    HY465761  10/17/2015 02:20:00 PM      013XX S CANAL ST  0560
# 995  10277641    HY465673  10/17/2015 02:15:00 PM    038XX W GLADYS AVE  1310
# 996  10277642    HY465669  10/17/2015 02:06:00 PM    012XX S WABASH AVE  1330
# 997  10278203    HY465666  10/17/2015 02:05:00 PM   027XX W WARREN BLVD  1310
# 998  10277671    HY465707  10/17/2015 02:05:00 PM  033XX W VAN BUREN ST  1811
#
#           Primary Type                   Description Location Description  \
# 994            ASSAULT                        SIMPLE   GROCERY FOOD STORE
# 995    CRIMINAL DAMAGE                   TO PROPERTY            APARTMENT
# 996  CRIMINAL TRESPASS                       TO LAND          GAS STATION
# 997    CRIMINAL DAMAGE                   TO PROPERTY                OTHER
# 998          NARCOTICS  POSS: CANNABIS 30GMS OR LESS               STREET
#
# ...

# %% [markdown]
# **the information of the dataset **

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    999 non-null    int64
#  1   Case Number           999 non-null    object
#  2   Date                  999 non-null    object
#  3   Block                 999 non-null    object
#  4   IUCR                  999 non-null    object
#  5   Primary Type          999 non-null    object
#  6   Description           999 non-null    object
#  7   Location Description  999 non-null    object
#  8   Arrest                999 non-null    bool
#  9   Domestic              999 non-null    bool
#  10  Beat                  999 non-null    int64
#  11  District              999 non-null    int64
#  12  Ward                  999 non-null    int64
#  13  Community Area        999 non-null    int64
#  14  FBI Code              999 non-null    object
# ...

# %%
df.shape
# Out:
# (999, 22)

# %% [markdown]
# **check the null values**

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.isnull().sum()
# Out:
# ID                        0
# Case Number               0
# Date                      0
# Block                     0
# IUCR                      0
# Primary Type              0
# Description               0
# Location Description      0
# Arrest                    0
# Domestic                  0
# Beat                      0
# District                  0
# Ward                      0
# Community Area            0
# FBI Code                  0
# X Coordinate            102
# Y Coordinate            102
# Year                      0
# Updated On                0
# Latitude                102
# Longitude               102
# Location                102
# dtype: int64

# %%
df=df.dropna(axis=0)
df.isnull().sum()
# Out:
# ID                      0
# Case Number             0
# Date                    0
# Block                   0
# IUCR                    0
# Primary Type            0
# Description             0
# Location Description    0
# Arrest                  0
# Domestic                0
# Beat                    0
# District                0
# Ward                    0
# Community Area          0
# FBI Code                0
# X Coordinate            0
# Y Coordinate            0
# Year                    0
# Updated On              0
# Latitude                0
# Longitude               0
# Location                0
# dtype: int64

# %% [markdown]
# **check the duplicate vaules**

# %%
df.duplicated().values.any()
# Out:
# False

# %% [markdown]
# **the display statistics of  mean std count**

# %%
df.describe()
# Out:
#                  ID         Beat    District        Ward  Community Area  \
# count  8.970000e+02   897.000000  897.000000  897.000000      897.000000
# mean   1.025573e+07  1184.849498   11.616499   23.705686       35.791527
# std    4.840318e+05   681.543242    6.806483   13.781632       21.257142
# min    2.215000e+04   111.000000    1.000000    1.000000        1.000000
# 25%    1.027807e+07   624.000000    6.000000   12.000000       22.000000
# 50%    1.027847e+07  1112.000000   11.000000   24.000000       30.000000
# 75%    1.027880e+07  1724.000000   17.000000   35.000000       53.000000
# max    1.028171e+07  2535.000000   25.000000   50.000000       77.000000
#
#        X Coordinate  Y Coordinate    Year    Latitude   Longitude
# count  8.970000e+02  8.970000e+02   897.0  897.000000  897.000000
# mean   1.163492e+06  1.888108e+06  2015.0   41.848588  -87.675506
# std    1.663489e+04  3.064705e+04     0.0    0.084299    0.060561
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Case Number', 'Date', 'Block', 'IUCR', 'Primary Type',
#        'Description', 'Location Description', 'Arrest', 'Domestic', 'Beat',
#        'District', 'Ward', 'Community Area', 'FBI Code', 'X Coordinate',
#        'Y Coordinate', 'Year', 'Updated On', 'Latitude', 'Longitude',
#        'Location'],
#       dtype='object')

# %%
plt.figure(figsize=(10,5))
sns.barplot(x ='Arrest',y='Primary Type',data =df)
plt.title("crime of Arrest type")
plt.show()

# %%
df.columns
# Out:
# Index(['ID', 'Case Number', 'Date', 'Block', 'IUCR', 'Primary Type',
#        'Description', 'Location Description', 'Arrest', 'Domestic', 'Beat',
#        'District', 'Ward', 'Community Area', 'FBI Code', 'X Coordinate',
#        'Y Coordinate', 'Year', 'Updated On', 'Latitude', 'Longitude',
#        'Location'],
#       dtype='object')

# %%
plt.figure(figsize=(15,10))
sns.barplot(x ='Arrest',y='Location Description', data=df)
plt.title("the Crime of Arrest loction ")
plt.show()

# %%
df.columns
# Out:
# Index(['ID', 'Case Number', 'Date', 'Block', 'IUCR', 'Primary Type',
#        'Description', 'Location Description', 'Arrest', 'Domestic', 'Beat',
#        'District', 'Ward', 'Community Area', 'FBI Code', 'X Coordinate',
#        'Y Coordinate', 'Year', 'Updated On', 'Latitude', 'Longitude',
#        'Location'],
#       dtype='object')

# %% [markdown]
# Remove the unwanted column to a dataset

# %%
new_df = df.drop(columns=['ID','Block','Year','Y Coordinate','Location','Latitude','Longitude','X Coordinate','Date','IUCR','Ward','FBI Code','Updated On','Case Number'])

# %%
new_df.columns
# Out:
# Index(['Primary Type', 'Description', 'Location Description', 'Arrest',
#        'Domestic', 'Beat', 'District', 'Community Area'],
#       dtype='object')

# %%
plt.figure(figsize=(3,3))
plt.bar(crime.index,crime)
plt.xticks(rotation=90)
plt.show()

# %%
new_df.columns
# Out:
# Index(['Primary Type', 'Description', 'Location Description', 'Arrest',
#        'Domestic', 'Beat', 'District', 'Community Area'],
#       dtype='object')

# %%
plt.figure(figsize=(14,6))
plt.hist(new_df["Beat"])
plt.show()

# %%
new_df.columns
# Out:
# Index(['Primary Type', 'Description', 'Location Description', 'Arrest',
#        'Domestic', 'Beat', 'District', 'Community Area'],
#       dtype='object')

# %%
from sklearn import preprocessing
label_encoder=preprocessing.LabelEncoder()
new_df['Primary Type']=label_encoder.fit_transform(new_df['Primary Type'])
new_df['Primary Type'].unique()

label_encoder=preprocessing.LabelEncoder()
new_df['Arrest']=label_encoder.fit_transform(new_df['Arrest'])
new_df['Arrest'].unique()

label_encoder=preprocessing.LabelEncoder()
new_df['Location Description']=label_encoder.fit_transform(new_df['Location Description'])
new_df['Location Description'].unique()

label_encoder=preprocessing.LabelEncoder()
new_df['Domestic']=label_encoder.fit_transform(new_df['Domestic'])
new_df['Domestic'].unique()

label_encoder=preprocessing.LabelEncoder()
new_df['Description']=label_encoder.fit_transform(new_df['Description'])
new_df['Description'].unique()
# Out:
# array([73, 28, 58, 95, 52,  3, 82,  0, 89, 63, 13, 38, 86, 19, 53, 55, 25,
#        34, 83, 61, 80, 20, 31, 76, 23,  5, 56, 37, 72, 75, 66, 51,  9, 65,
#        90, 81, 10, 87, 84, 69, 24, 50, 46, 54, 39, 67, 88, 33, 49, 16, 44,
#        91, 59,  7, 40, 96, 21, 78, 11, 36, 18, 35, 43,  8, 79, 48,  2, 71,
#        42, 70, 77, 62, 32,  1, 94, 22,  6, 74, 60, 29, 17, 15, 64, 57, 85,
#        45, 41,  4, 68, 92, 30, 47, 93, 27, 14, 12, 26])

# %%
new_df.head()
# Out:
#    Primary Type  Description  Location Description  Arrest  Domestic  Beat  \
# 0             1           73                    38       0         0   313
# 1             2           28                     5       1         1   411
# 2            13           58                    25       1         0   423
# 4            15           95                     5       1         0   421
# 5            14           52                    37       0         1  1611
#
#    District  Community Area
# 0         3              42
# 1         4              45
# 2         4              46
# 4         4              43
# 5        16              10

# %%
new_df.shape
# Out:
# (897, 8)

# %%
# Assuming 'Arrest' is the target variable and it is at the 5th index (column) in the DataFrame.
# Change the column index to 5 (or the appropriate index of your target variable)
y = new_df.iloc[:, 5].values

# %%
from sklearn.model_selection import train_test_split

# Remove the 'stratify' parameter
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

print(X_train.shape)
print(y_train.shape)
# Out:
# (717, 8)
# (717,)

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# Assuming 'new_df' is your DataFrame


numerical_features = new_df.select_dtypes(include=['number']).columns
# or if you know the specific columns: numerical_features = new_df.columns[1:14] # Select columns from index 1 to 13

X = new_df[numerical_features].values

y = new_df.iloc[:, -1].values  # This selects the last column



# Split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Apply StandardScaler only to the numerical features
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import r2_score  # Import accuracy_score for classification

# Train the model
clf = LogisticRegression(random_state=0)
clf.fit(X_train, y_train)  # Use X_train and y_train for training

# Make predictions
y_pred = clf.predict(X_test)

# Evaluate the model using accuracy_score for classification
score = r2_score(y_test, y_pred)
print(score)
# Out:
# 0.9460268372964628
